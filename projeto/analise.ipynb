# %% [markdown]
# # Super Computação - Análise dos resultados
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Heuristíca Gananciosa:**

# %%
fc = pd.read_csv("./../projeto/resultados/gananciosa_filmes_categorias.csv")
fm = pd.read_csv("./../projeto/resultados/gananciosa_medias.csv")

# %%
fc
# Out:
#       n_filmes  n_categorias  t_restante  t_execucao  v_filmes
# 0         1000             1          21    0.000042         1
# 1         1000             2          18    0.000042         3
# 2         1000             3          11    0.000042         5
# 3         1000             4           4    0.000046         9
# 4         1000             5           0    0.000053        10
# ...        ...           ...         ...         ...       ...
# 2428     49000            46           0    0.001943        14
# 2429     49000            47           0    0.002371        11
# 2430     49000            48           0    0.001996        11
# 2431     49000            49           0    0.002618        10
# 2432     49000            50           0    0.001987        12
#
# [2433 rows x 5 columns]

# %% [markdown]
# Filmes totais x Filmes vistos

# %%
plt.figure(figsize=(10, 5))
for i in range(2, 16,2):
    fxf = fc[fc["n_categorias"] == i]
    plt.plot(fxf["n_filmes"], fxf["v_filmes"], label=str(i))
plt.legend(title="categorias") 
plt.title('Filmes x Filmes (Gananciosa)')
plt.xlabel('número de filmes')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Categorias x Filmes assistidos

# %%
plt.figure(figsize=(10, 5))
for i in range(1000, 50000,8000):
    fxc = fc[fc["n_filmes"] == i]
    plt.plot(fxc["n_categorias"], fxc["v_filmes"], label=str(i))
plt.legend(title="filmes") 
plt.title('Categorias x Filmes (Gananciosa)')
plt.xlabel('número de categorias')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Filmes x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
for i in range(1, 50,6):
    fxf = fc[fc["n_categorias"] == i]
    plt.plot(fxf["n_filmes"], fxf["t_execucao"], label=str(i))
plt.legend(title="categorias") 
plt.title('Filmes x Tempo de Execução (Gananciosa)')
plt.xlabel('número de filmes')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Categorias x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
for i in range(1000, 50000,6000):
    fxc = fc[fc["n_filmes"] == i]
    plt.plot(fxc["n_categorias"], fxc["t_execucao"], label=str(i))
plt.legend(title="filmes") 
plt.title('Categorias x Tempo de Execução (Gananciosa)')
plt.xlabel('número de categorias')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Tempo Médio x Filmes Assistidos

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    fxc = fm[fm["n_filmes"] == i]
    plt.plot(x, fxc["v_filmes"], label=str(i))
plt.legend(title="filmes") 
plt.title('Média de Duração x Filmes (Gananciosa)')
plt.xlabel('número médio de horas')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Tempo Médio x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    fxc = fm[fm["n_filmes"] == i]
    plt.plot(x, fxc["t_execucao"], label=str(i))
plt.legend(title="filmes") 
plt.title('Média de Duração x Tempo de Execução (Gananciosa)')
plt.xlabel('número médio de horas')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# ### **Heuristíca Aleatória:**

# %%
fc = pd.read_csv("./../projeto/resultados/aleatoria_filmes_categorias.csv")
fm = pd.read_csv("./../projeto/resultados/aleatoria_medias.csv")

# %% [markdown]
# Filmes totais x Filmes vistos

# %%
plt.figure(figsize=(10, 5))
for i in range(5, 50, 8):
    fxf = fc[fc["n_categorias"] == i]
    plt.plot(fxf["n_filmes"], fxf["v_filmes"], label=str(i))
plt.legend(title="categorias") 
plt.title('Filmes x Filmes (Aleatória)')
plt.xlabel('número de filmes')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Categorias x Filmes assistidos

# %%
plt.figure(figsize=(10, 5))
for i in range(1000, 50000,8000):
    fxc = fc[fc["n_filmes"] == i]
    plt.plot(fxc["n_categorias"], fxc["v_filmes"], label=str(i))
plt.legend(title="filmes") 
plt.title('Categorias x Filmes (Aleatória)')
plt.xlabel('número de categorias')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Filmes x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
for i in range(1, 50,6):
    fxf = fc[fc["n_categorias"] == i]
    plt.plot(fxf["n_filmes"], fxf["t_execucao"], label=str(i))
plt.legend(title="categorias") 
plt.title('Filmes x Tempo de Execução (Aleatória)')
plt.xlabel('número de filmes')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Categorias x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
for i in range(1000, 50000,6000):
    fxc = fc[fc["n_filmes"] == i]
    plt.plot(fxc["n_categorias"], fxc["t_execucao"], label=str(i))
plt.legend(title="filmes") 
plt.title('Categorias x Tempo de Execução (Aleatória)')
plt.xlabel('número de categorias')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Tempo Médio x Filmes Assistidos

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    fxc = fm[fm["n_filmes"] == i]
    plt.plot(x, fxc["v_filmes"], label=str(i))
plt.legend(title="filmes") 
plt.title('Média de Duração x Filmes (Gananciosa)')
plt.xlabel('número médio de horas')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Tempo Médio x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    fxc = fm[fm["n_filmes"] == i]
    plt.plot(x, fxc["t_execucao"], label=str(i))
plt.legend(title="filmes") 
plt.title('Média de Duração x Tempo de Execução (Gananciosa)')
plt.xlabel('número médio de horas')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# ### Comparação Gananciosa x Aleatória

# %%
fcg = pd.read_csv("./../projeto/resultados/gananciosa_filmes_categorias.csv")
fmg = pd.read_csv("./../projeto/resultados/gananciosa_medias.csv")
fca = pd.read_csv("./../projeto/resultados/aleatoria_filmes_categorias.csv")
fma = pd.read_csv("./../projeto/resultados/aleatoria_medias.csv")

# %% [markdown]
# Filmes totais x Filmes vistos

# %%
plt.figure(figsize=(10, 5))

for i in range(1, 50, 6):
    a = fca[fca["n_categorias"] == i]
    g = fcg[fcg["n_categorias"] == i]
    plt.plot(g["n_filmes"], g["v_filmes"], label="Gananciosa", color = "red")
    plt.plot(a["n_filmes"], a["v_filmes"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="heurísticas") 
plt.title('Filmes x Filmes')
plt.xlabel('número de filmes')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Categorias x Filmes assistidos

# %%
plt.figure(figsize=(10, 5))

for i in range(1000, 50000,6000):
    a = fca[fca["n_filmes"] == i]
    g = fcg[fcg["n_filmes"] == i]
    plt.plot(g["n_categorias"], g["v_filmes"], label="Gananciosa", color = "red")
    plt.plot(a["n_categorias"], a["v_filmes"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="heurísticas") 
plt.title('Categorias x Filmes')
plt.xlabel('número de categorias')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Filmes x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))

for i in range(1, 50, 6):
    a = fca[fca["n_categorias"] == i]
    g = fcg[fcg["n_categorias"] == i]
    plt.plot(g["n_filmes"], g["t_execucao"], label="Gananciosa", color = "red")
    plt.plot(a["n_filmes"], a["t_execucao"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="heurísticas") 
plt.title('Filmes x Tempo de Execução')
plt.xlabel('número de filmes')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Categorias x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))

for i in range(1000, 50000,6000):
    a = fca[fca["n_filmes"] == i]
    g = fcg[fcg["n_filmes"] == i]
    plt.plot(g["n_categorias"], g["t_execucao"], label="Gananciosa", color = "red")
    plt.plot(a["n_categorias"], a["t_execucao"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="heurísticas") 
plt.title('Categorias x Tempo de Execução')
plt.xlabel('número de categorias')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')

# %% [markdown]
# Tempo Médio x Filmes Assistidos

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    a = fma[fma["n_filmes"] == i]
    g = fmg[fmg["n_filmes"] == i]
    plt.plot(x, g["v_filmes"], label="Gananciosa", color = "red")
    plt.plot(x, a["v_filmes"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="filmes") 
plt.title('Média de Duração x Filmes')
plt.xlabel('número médio de horas')
plt.ylabel('filmes assistidos')
# Out:
# Text(0, 0.5, 'filmes assistidos')

# %% [markdown]
# Tempo Médio x Tempo de Execução

# %%
plt.figure(figsize=(10, 5))
x = np.arange(1,13,1)
for i in range(1000, 50000,6000):
    a = fma[fma["n_filmes"] == i]
    g = fmg[fmg["n_filmes"] == i]
    plt.plot(x, g["t_execucao"], label="Gananciosa", color = "red")
    plt.plot(x, a["t_execucao"], label="Aleatória", color = "blue")
plt.legend(["Gananciosa", "Aleatória"],title="filmes") 
plt.title('Média de Duração x Tempo de Execução')
plt.xlabel('número médio de horas')
plt.ylabel('tempo[s]')
# Out:
# Text(0, 0.5, 'tempo[s]')
